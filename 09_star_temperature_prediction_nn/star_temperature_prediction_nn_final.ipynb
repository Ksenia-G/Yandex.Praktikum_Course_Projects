# %% [markdown]
#   <div class="alert alert-info">
#   Привет, Ксения! Меня зовут Светлана Чих и я буду проверять твой проект. Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе. Предлагаю общаться на «ты». Но если это не удобно - дай знать, и мы перейдем на «вы».
#
#   <div class="alert alert-success">
#   <b>👍 Успех:</b> Зелёным цветом отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах.
#   </div>
#   <div class="alert alert-warning">
#   <b>🤔 Рекомендация:</b> Жёлтым цветом выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#   </div>
#   <div class="alert alert-danger">
#   <b>😔 Необходимо исправить:</b> Красным цветом выделены комментарии, без исправления которых, я не смогу принять проект :(
#   </div>
#   <div class="alert alert-info">
#   <b>👂 Совет:</b> Какие-то дополнительные материалы
#   </div>
#   Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом.
#   Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#   <div class="alert alert-info"> <b>🎓 Комментарий студента:</b> Например, вот так.</div>
#   Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#    </div>

# %% [markdown]
# <div class="alert alert-info">
#   <b>🎓 Комментарий студента:</b> Светлана, привет! Внесла правки по твоим замечаниям.
#     1. Перевела все на русский. Сори, раньше проблем не вызывало. Я делаю сразу для портфолио, а там все на англ. :-)
#     2. Добавила ссылку на данные. Делала локально и подгружала со своего компа. Про библиотеку os - спасибо, учту на будущее.
#     3. Не все фишки, которые у меня работали локально, удалось настроить тут (например модуль torchmetrics). Я их закомментила тут, не стала удалять, т.к. хочу потом вернуть обратно. Надеюсь, это не проблема.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Обучение на курсе ведется на русском языке (это язык заказчика и задание было дано именно на этом языке), поэтому все рассуждения и выводы должны быть на русском языке (ты можешь оставить дублирование на других языках, но только как дополнение). я продолжу проверку проекта после этого исправления. Обрати внимание, что сейчас тетрадка не выполняется в тренажере, что так же не дают мне провести проверку, нужно исправить путь к файлу.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:</s>
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <b>🎓 Комментарий студента:</b> Светлана, привет! Внесла правки по твоим замечаниям.
#     1. Перевела все на русский. Сори, раньше проблем не вызывало. Я делаю сразу для портфолио, а там все на англ. :-)
#     2. Добавила ссылку на данные. Делала локально и подгружала со своего компа. Про библиотеку os - спасибо, учту на будущее.
#     3. Не все фишки, которые у меня работали локально, удалось настроить тут (например модуль torchmetrics). Я их закомментила тут, не стала удалять, т.к. хочу потом вернуть обратно. Надеюсь, это не проблема.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Привет! Закомментированный код можно оставить
# </div>

# %% [markdown]
# # Описание проекта

# %% [markdown]
# **Прогнозирование температуры звезды**
#
# **Цель:** Разработать нейронную сеть для предсказания абсолютной температуры на поверхности звезды.
#
# **План действий:**
#
# 1. Загрузить исходные данные из файла.
# 1. Провести исследовательский анализ данных.
# 1. Подготовить данные для построения модели.
# 1. Построить простую модель нейронной сети (baseline).
# 1. Обучить модель.
# 1. Построить график «Факт — Прогноз», где по горизонтальной оси будут указаны индексы звёзд, а по вертикальной — температура в Кельвинах

# %% [markdown]
# # 0. Подготовка ноутбука к работе

# %% [markdown]
# **Импорты**

# %%
pip install phik -q

# %%
pip install torch -q

# %%
pip install skorch -q

# %%
import pandas as pd
import numpy as np
import random

import matplotlib.pyplot as plt
import matplotlib.ticker
import seaborn as sns
from phik import phik_matrix

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import root_mean_squared_error

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
#import torchmetrics
#from torchmetrics import MeanSquaredError

from skorch import NeuralNetRegressor

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Импортированы нужные библиотеки!
# </div>

# %% [markdown]
# **Функции**

# %%
# Function to display the main information about a data frame
def display_main_info(df):
    """
    Displays key information about the DataFrame for exploratory data analysis.
    
    Args:
        df (pandas.DataFrame): The DataFrame to be analyzed.
        
    Displays:
        - The first few rows of the DataFrame.
        - Data types and non-null counts of each column.
        - The shape (number of rows and columns) of the DataFrame.
        - The number of duplicate rows in the DataFrame.
        - The proportion of missing data for each column.
    """
    
    print('________________Head________________')
    display(df.head())
    
    print('________________Data Types Info________________')
    display(df.info())
    
    print('________________Shape________________')
    display(df.shape)
    
    print('________________Duplicates________________')
    display(df.duplicated().sum())
    
    print('________________Proportion of Missing Data________________')
    display(df.isna().mean())

# %%
# Function to display statistical info
def show_stats(column_name: str):
    """
    Display summary statistics for a specified column in the dataset.

    """

    print(f'Statistics for {column_name}')
    display(df[[column_name]].describe().T)

# %%
# Function to display density and box plots for numeric data
def plot_density_and_boxplot(data, column):
    """
    Plot density plot and boxplot for a given column in a DataFrame.

    Parameters:
    - df: pandas DataFrame
    - column: str

    Returns:
    - None
    """
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Plot density plot
    sns.histplot(data[column], bins=50, color='lightgreen', kde=True, ax=axs[0])
    axs[0].set_title(f'Density Plot of {column}')

    # Plot boxplot
    axs[1].boxplot(data[column], vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
    axs[1].set_title(f'Boxplot of {column}')

    # Adjust layout
    plt.tight_layout()

    # Show plot
    plt.show()

# %%
# Function that replaces rare categories based on a threshold
def remove_rare_categories(df, column_name, threshold):
    """
    Replaces rare categories in a specified column with 'Other' based on a threshold.

    Parameters:
    - df: pandas DataFrame
    - column_name: str, name of the column to process
    - threshold: float, categories with frequency <= threshold will be replaced

    Returns:
    - Updated Series with replaced rare categories and their normalized value counts.
    """

    category_counts = df[column_name].value_counts(normalize=True)
    rare_categories = category_counts[category_counts <= threshold].index
    df[column_name + '_new'] = df[column_name].apply(lambda x: 'Other' if x in rare_categories else x)
    
    return df[column_name + '_new'].value_counts(normalize=True)

# %%
# Function that displays a bar chart for discrete values
def plot_bar_chart(data, column, dataset_name="Dataset"):

    value_counts = data[column].value_counts().sort_index()
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.bar(value_counts.index, value_counts.values, color='yellow', edgecolor='black')

    ax.set_title(f"Bar Chart of {column}", fontsize=16)
    ax.set_xlabel(column, fontsize=14)
    ax.set_ylabel("Frequency", fontsize=14)
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    plt.tight_layout()

    plt.show()

# %%
# Function that plots a Phi_k correlation matrix
def plot_phik_heatmap(df, interval_cols, title='Phi_k Correlation Matrix'):
    """
    Plot a heatmap with a green color scheme for the Phi_k correlation matrix.

    Parameters:
    - df: pandas DataFrame
    - interval_cols: list of column names to be considered as interval columns for the Phi_k matrix
    - title: str, title of the plot (default is 'Phi_k Correlation Matrix')

    Returns:
    - None
    """
    # Calculate Phi_k matrix
    matrix = phik_matrix(df, interval_cols=interval_cols)
    
    # Plot heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(matrix, annot=True, cmap='Greens', vmin=-1, vmax=1)
    plt.title(title)
    plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Подготовлены нужные функции!
# </div>

# %% [markdown]
# **Константы**

# %%
RANDOM_STATE = 42

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.use_deterministic_algorithms(True)

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Не стоит фиксировать случайные величины 0, это может вызывать ошибки
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <b>🎓 Комментарий студента:</b> Поняла, спасибо большое! Учту в дальнейшем.
# </div>

# %% [markdown]
# # 1. Исследование данных

# %% [markdown]
# ## 1.1 Загрузка данных

# %%
df = pd.read_csv('https://code.s3.yandex.net/datasets/6_class.csv')

# %% [markdown]
# ## 1.2 Основная информация

# %%
display_main_info(df)
# Out:
# ________________Head________________
#    Unnamed: 0  Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# 0           0             3068          0.002400        0.1700
# 1           1             3042          0.000500        0.1542
# 2           2             2600          0.000300        0.1020
# 3           3             2800          0.000200        0.1600
# 4           4             1939          0.000138        0.1030
#
#    Absolute magnitude(Mv)  Star type Star color
# 0                   16.12          0        Red
# 1                   16.60          0        Red
# 2                   18.70          0        Red
# 3                   16.65          0        Red
# 4                   20.06          0        Red
# ________________Data Types Info________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
# ...

# %%
show_stats('Unnamed: 0')
# Out:
# Statistics for Unnamed: 0
#             count   mean       std  min    25%    50%     75%    max
# Unnamed: 0  240.0  119.5  69.42622  0.0  59.75  119.5  179.25  239.0

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.rename(columns={
    'Temperature (K)': 'temperature',
    'Luminosity(L/Lo)': 'luminosity',
    'Radius(R/Ro)': 'radius',
    'Absolute magnitude(Mv)': 'magnitude',
    'Star type': 'star_type',
    'Star color': 'star_color'
}, inplace=True)

# %%
numeric = df.select_dtypes(include='number').columns.tolist()

# %%
for col in df[numeric]:
    show_stats(col)
# Out:
# Statistics for temperature
#              count        mean          std     min      25%     50%      75%  \
# temperature  240.0  10497.4625  9552.425037  1939.0  3344.25  5776.0  15055.5
#
#                  max
# temperature  40000.0
# Statistics for luminosity
#             count           mean           std      min       25%     50%  \
# luminosity  240.0  107188.361635  179432.24494  0.00008  0.000865  0.0705
#
#                  75%       max
# luminosity  198050.0  849420.0
# Statistics for radius
#         count        mean         std     min      25%     50%    75%     max
# radius  240.0  237.157781  517.155763  0.0084  0.10275  0.7625  42.75  1948.5
# Statistics for magnitude
#            count      mean        std    min     25%    50%      75%    max
# magnitude  240.0  4.382396  10.532512 -11.92 -6.2325  8.313  13.6975  20.06
# Statistics for star_type
#            count  mean       std  min  25%  50%  75%  max
# ...

# %%
df['star_color'].value_counts(normalize=True)
# Out:
# star_color
# Red                   0.466667
# Blue                  0.229167
# Blue-white            0.108333
# Blue White            0.041667
# yellow-white          0.033333
# White                 0.029167
# Blue white            0.012500
# Yellowish White       0.012500
# white                 0.012500
# Whitish               0.008333
# Orange                0.008333
# yellowish             0.008333
# Pale yellow orange    0.004167
# White-Yellow          0.004167
# Blue                  0.004167
# Yellowish             0.004167
# Orange-Red            0.004167
# Blue white            0.004167
# Blue-White            0.004167
# Name: proportion, dtype: float64

# %% [markdown]
# **Наблюдения:**
#
# 1. Количество наблюдений соответствует описанию (240 строк). Датасет не содержит пропущенных значений и точных дубликатов.
# 2. Обнаружен лишний столбец (`Unnamed: 0`), дублирующий нумерацию строк, который был удалён.
# 3. Названия столбцов приведены к удобному формату для дальнейшего анализа.
# 4. Датасет содержит 5 признаков и 1 целевую переменную (`Temperature (K)`).
# 5. Для `Temperature (K)`, `Luminosity (L/Lo)` и `Radius (R/Ro)` медиана меньше среднего, что указывает на скошенность распределений и наличие выбросов.
# 6. Признак "Star type" является категориальным.
# 7. Признак "Star color" содержит дублирующиеся значения.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Датасет загружен и просмотрен!
# </div>

# %% [markdown]
# ## 1.3 EDA

# %%
for col in df[numeric]:
    plot_density_and_boxplot(df, col)

# %%
df['star_color'].unique()
# Out:
# array(['Red', 'Blue White', 'White', 'Yellowish White', 'Blue white',
#        'Pale yellow orange', 'Blue', 'Blue-white', 'Whitish',
#        'yellow-white', 'Orange', 'White-Yellow', 'white', 'Blue ',
#        'yellowish', 'Yellowish', 'Orange-Red', 'Blue white ',
#        'Blue-White'], dtype=object)

# %%
df['star_color'] = df['star_color'].replace({
    'Blue White': 'Blue-white',
    'Blue white': 'Blue-white',
    'Blue white ': 'Blue-white',
    'Blue-White': 'Blue-white',
    'Blue ': 'Blue',
    'Whitish': 'White',
    'white': 'White',
    'Yellowish White': 'Yellow-white',
    'yellow-white': 'Yellow-white',
    'White-Yellow': 'Yellow-white',
    'yellowish': 'Yellowish'
})

# %%
df['star_color'].value_counts(normalize=True)
# Out:
# star_color
# Red                   0.466667
# Blue                  0.233333
# Blue-white            0.170833
# White                 0.050000
# Yellow-white          0.050000
# Yellowish             0.012500
# Orange                0.008333
# Pale yellow orange    0.004167
# Orange-Red            0.004167
# Name: proportion, dtype: float64

# %%
remove_rare_categories(df, 'star_color', 0.04)
# Out:
# star_color_new
# Red             0.466667
# Blue            0.233333
# Blue-white      0.170833
# White           0.050000
# Yellow-white    0.050000
# Other           0.029167
# Name: proportion, dtype: float64

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> White и Yellow-white  лучше оставить отдельными категориями, возьми порог 0.04. Самая идея отличная!</s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <b>🎓 Комментарий студента:</b> Поняла, спасибо! Откорректировала.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Супер!
# </div>

# %%
plot_bar_chart(df, 'star_color_new')

# %% [markdown]
# **Выводы:**
#
# **Целевая переменная `Temperature (K)`:**
# Медиана (~5,776 K) почти в два раза меньше среднего значения (~10,497 K), что указывает на скошенное распределение. Вероятно, температуры звёзд имеют сильный положительный перекос, где большинство значений сосредоточено в области более низких температур.
#
# **Признак `Luminosity (L/Lo)`:**
# Аналогично, светимость звёзд также демонстрирует сильный положительный перекос. Большая разница между медианой и средним значением свидетельствует о наличии экстремальных значений (очень ярких звёзд), которые вытягивают среднее вверх.
#
# **Признак `Radius (R/Ro)`:**
# Радиус звёзд показывает похожую тенденцию: значительное расхождение между медианой и средним указывает на наличие выбросов — очень крупных звёзд.
#
# **Признак `Absolute Magnitude (Mv)`:**
# Среднее значение (+4.38) ближе к медиане (+8.31), но минимальные значения достигают -11.92, что говорит о наличии крайне ярких звёзд. Эти значения сильно влияют на динамический диапазон данных.
#
# **Признак `Star Type`:**
# Признак `Star type` является дискретным. Распределение типов звёзд равномерное в диапазоне значений (от 0 до 5).
#
# **Обработка данных:**
#
# - **Star Color:**
# Редкие категории объединены в общую категорию "Other". Однако, данные имеют значительное смещение в сторону звёзд с цветами "Red", "Blue" и "Blue-White".
#
# - **Нормализация данных:**
# Перед использованием данных в моделях машинного обучения необходимо произвести их нормализацию.
#
# - **Стратификация по `Star Color`:**
# Наблюдается несбалансированность в признаке `Star color`. Для устранения дисбаланса следует выполнить стратификацию по этому признаку.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Идея со стратификацией тоже очень хорошая!
# </div>

# %% [markdown]
# # 2. Проверка на мультиколлинеарность

# %%
interval_cols = ['temperature', 'luminosity', 'radius', 'magnitude']

# %%
plot_phik_heatmap(df, interval_cols=interval_cols)

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Нужно построить диаграммы рассеяния, разделив данные цветом по типу</s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <b>🎓 Комментарий студента:</b> Добавила. См. ниже
# </div>

# %%
sns.set(style="ticks", context="talk")
plt.figure(figsize=(15, 10))

plots = [
    ('luminosity', 'Luminosity vs Temperature'),
    ('radius', 'Radius vs Temperature'),
    ('magnitude', 'Magnitude vs Temperature'),
    ('star_color_new', 'Star Color vs Temperature')
]

for i, (x_column, title) in enumerate(plots, 1):
    plt.subplot(2, 2, i)
    sns.scatterplot(x=x_column, y='temperature', hue='star_type', palette='viridis', data=df)
    plt.title(title)
    plt.xlabel(x_column.replace('_', ' ').capitalize())
    plt.ylabel('Temperature')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы:**
#
# Сильной корреляции (>= 0.99) между признаками не наблюдается.
#
# На данных диаграммах можно увидеть несколько  интересных взаимосвязей между температурой звезд и другими их характеристиками. Например, что более горячие звезды более яркие (что соответствует закону Стефана-Больцмана). Также, звезды с более высоким радиусом могут иметь более низкую температуру (как правило, красные гиганты), но в случае более мелких и горячих звезд (например, белые карлики), температура может быть высокой при меньшем радиусе. График может показывает разнообразие типов звезд, где для некоторых температур радиус значительно варьируется.
# Можно увидеть, что более холодные звезды могут иметь меньшую видимую яркость.
#
# Цвет звезды напрямую связан с её температурой: более горячие звезды обычно выглядят синими или белыми, а холодные — красными или оранжевыми. Модно увидеть, как цвет звезды изменяется в зависимости от её температуры. Например, красные звезды имеют более низкую температуру, а синие — высокую.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Отличное исследование!
# </div>

# %% [markdown]
# # 3. Моделирование

# %% [markdown]
# ## 3.1 Подготовка данных

# %%
cols_to_drop = ['star_color']

df = df.drop(columns=cols_to_drop)

# %%
df.head()
# Out:
#    temperature  luminosity  radius  magnitude  star_type star_color_new
# 0         3068    0.002400  0.1700      16.12          0            Red
# 1         3042    0.000500  0.1542      16.60          0            Red
# 2         2600    0.000300  0.1020      18.70          0            Red
# 3         2800    0.000200  0.1600      16.65          0            Red
# 4         1939    0.000138  0.1030      20.06          0            Red

# %%
df['luminosity_log'] = np.log(df['luminosity'])

# %%
df['radius_log'] = np.log(df['radius'])

# %%
# Define the columns for numerical features, categorical features, and the target variable
num_cols = ['luminosity', 'radius', 'magnitude', 'luminosity_log', 'radius_log']
cat_cols = ['star_color_new', 'star_type']
target = 'temperature'

# %% [markdown]
# <div class="alert alert-danger">
#     <s><b>😔 Необходимо исправить:</b> 'star_type' тоже категориальный признак</s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <b>🎓 Комментарий студента:</b> Поняла. Исправила.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
# Split the dataset into training, test, and validation sets
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(columns=[target]),
    df[target],
    train_size=0.8,
    random_state=RANDOM_STATE,
    shuffle=True,
    stratify=df['star_color_new']
)

# Check the shape of the resulting datasets
X_train.shape, X_test.shape
y_train.shape, y_test.shape
# Out:
# ((192,), (48,))

# %%
# Define preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),  # Standardize numerical features
        ('cat', OneHotEncoder(drop='first', sparse_output=False), cat_cols)  # One-hot encode categorical features
    ]
)

# Fit and transform
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Для кодирования категориальных признаков используется OneHotEncoder, а не get_dummies, подробно можно посмотреть здесь</s>
#
# https://colab.research.google.com/drive/1_gAMXcQKoCShB_l8FNtYEejMnosm9mvt?usp=sharing#scrollTo=organized-pierce
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <b>🎓 Комментарий студента:</b> Поняла. Исправила.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
X_train_tensor = torch.FloatTensor(X_train)
X_test_tensor = torch.FloatTensor(X_test)

y_train_tensor = torch.FloatTensor(y_train.values)
y_test_tensor = torch.FloatTensor(y_test.values)

# %% [markdown]
# ## 3.2 Базовая конфигурация (1 скрытый слой)

# %%
# Input and output numbers of neurons
input_dim = X_train_tensor.shape[1]
output_dim = 1

# %%
# Define a simple neural network class with 1 hidden layer
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, n_hidden_1, output_dim):
        super(NeuralNetwork, self).__init__()

        self.fc1 = nn.Linear(input_dim, n_hidden_1)
        self.act1 = nn.ReLU()

        self.fc2 = nn.Linear(n_hidden_1, output_dim)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act1(x)

        x = self.fc2(x)
        return x

# %%
# List of different values for the number of hidden neurons
n_hidden_neurons = [input_dim, 16, 32, 64]
n_epochs = 1000 

# Loss function (Mean Squared Error) for training
loss = nn.MSELoss()

# %%
# Function to train the neural network
def train_neural_network(neural_network, n_epochs, n_layers=1):
    """
    This function trains the neural network model for a given number of epochs and calculates the RMSE on validation data.
    
    Parameters:
    neural_network (nn.Module): The neural network model to be trained.
    n_epochs (int): The number of epochs for training the model.
    n_layers (int, optional): The number of layers in the neural network. Default is 1.
    
    The function prints the RMSE value at the end of the training process for each epoch.
    """
    for epoch in range(n_epochs):
        neural_network.train()
        optimizer.zero_grad()
        
        y_pred = neural_network(X_train_tensor).flatten()
        loss_value = loss(y_pred, y_train_tensor)
        
        loss_value.backward() 
        
        optimizer.step()


    neural_network.eval()
    
    with torch.no_grad():
        test_preds = neural_network.forward(X_test_tensor)
        rmse = root_mean_squared_error(y_test_tensor, test_preds)
        
        if n_layers == 1:
            print(f"Neurons: {number}, RMSE: {rmse:.4f}")
        else:
            print(f"Neurons_1: {number_1}, Neurons_2: {number_2}, RMSE: {rmse:.4f}")

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Молодец, что помнишь о переводе сети в режимы обучения и тестирования!
# </div>

# %%
# Loop over different numbers of hidden neurons and train the model for each
for number in n_hidden_neurons:

    baseline_1 = NeuralNetwork(input_dim=input_dim, n_hidden_1=number, output_dim=output_dim)

    optimizer = torch.optim.Adam(baseline_1.parameters(), lr=1e-3)
    
    train_neural_network(baseline_1, n_epochs)
# Out:
# Neurons: 15, RMSE: 10894.6234
# Neurons: 16, RMSE: 10886.5839
# Neurons: 32, RMSE: 10774.0739
# Neurons: 64, RMSE: 10600.0261

# %% [markdown]
# Построение графика с предсказаниями лучшей однойслойной архитектуры.

# %%
n_hidden_1 = 64
learning_rate = 1e-3

neural_network = NeuralNetwork(input_dim=input_dim, n_hidden_1=n_hidden_1, output_dim=output_dim)
optimizer = torch.optim.Adam(neural_network.parameters(), lr=learning_rate)
loss = nn.MSELoss()

for epoch in range(n_epochs):
    neural_network.train()
    optimizer.zero_grad()

    y_pred = neural_network(X_train_tensor).flatten()
    loss_value = loss(y_pred, y_train_tensor)

    loss_value.backward()
    optimizer.step()

neural_network.eval()
with torch.no_grad():
    predictions = neural_network(X_test_tensor).flatten()
    metric = torch.sqrt(loss(predictions, y_test_tensor)).item()

print(f"Neurons: {n_hidden_1}, RMSE: {metric:.4f}")

# Visualisation
predicted = pd.DataFrame(predictions.numpy(), columns=['temperature'])
actual = pd.DataFrame(y_test_tensor.numpy(), columns=['temperature'])


fig, ax = plt.subplots(figsize=[20, 6])
indices = range(len(predicted))
plt.bar(indices, predicted['temperature'], color='steelblue', label='Predicted', alpha=0.7, width=0.4, align='center')
plt.bar(indices, actual['temperature'], color='coral', label='Actual', alpha=0.7, width=0.2, align='edge')
plt.title('Star Temperature (K) Predicted vs Actual', fontsize=16)
plt.xlabel('Stars', fontsize=14)
plt.ylabel('Temperature (K)', fontsize=14)
ax.legend()
plt.show()
# Out:
# Neurons: 64, RMSE: 10611.1914

# %% [markdown]
# Лучший результат, достигнутый с однослойной архитектурой, составляет RMSE: 10600.0261, что более чем в два раза превышает необходимую метрику. Из графика также видно, что модель плохо справляется с предсказанием.

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> После каждого варианта должен быть график факт-прогноз с описанием</s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <b>🎓 Комментарий студента:</b> Поняла. Добавила.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# ## 3.3 Базовая конфигурация 2 (2 скрытых слоя)

# %%
# Define a simple neural network class with 2 hidden layers
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, n_hidden_1, n_hidden_2, output_dim):
        super(NeuralNetwork, self).__init__()

        # First fully connected layer
        self.fc1 = nn.Linear(input_dim, n_hidden_1)
        self.act1 = nn.ReLU()

        # Second fully connected layer
        self.fc2 = nn.Linear(n_hidden_1, n_hidden_2)
        self.act2 = nn.ReLU()

        # Third fully connected layer
        self.fc3 = nn.Linear(n_hidden_2, output_dim)

    def forward(self, x):
        # Forward pass through layers and activations
        x = self.fc1(x)
        x = self.act1(x)

        x = self.fc2(x)
        x = self.act2(x)

        x = self.fc3(x)

        return x

# %%
# List of different values for the number of hidden neurons
n_hidden_neurons_1 = [16, 32, 64]
n_hidden_neurons_2 = [16, 32, 64]

# %%
# Loop over different combinations of hidden neurons and train the model for each
for number_1 in n_hidden_neurons_1:
    for number_2 in n_hidden_neurons_2:
        baseline_2 = NeuralNetwork(input_dim=input_dim, n_hidden_1=number_1, n_hidden_2=number_2, output_dim=output_dim)
        optimizer = torch.optim.Adam(baseline_2.parameters(), lr=0.1)
        train_neural_network(baseline_2, n_epochs, n_layers=2)
# Out:
# Neurons_1: 16, Neurons_2: 16, RMSE: 4129.9239
# Neurons_1: 16, Neurons_2: 32, RMSE: 4770.6214
# Neurons_1: 16, Neurons_2: 64, RMSE: 4735.4368
# Neurons_1: 32, Neurons_2: 16, RMSE: 4353.2144
# Neurons_1: 32, Neurons_2: 32, RMSE: 4733.5153
# Neurons_1: 32, Neurons_2: 64, RMSE: 5285.0527
# Neurons_1: 64, Neurons_2: 16, RMSE: 4993.1625
# Neurons_1: 64, Neurons_2: 32, RMSE: 5431.6047
# Neurons_1: 64, Neurons_2: 64, RMSE: 5971.8845

# %% [markdown]
# Метрика на нейронной сети с двумя скрытыми слоями значительно улучшилась и теперь достигает 4129.9239

# %% [markdown]
# Построение графика с предсказаниями лучшей двухслойной архитектуры.

# %%
# Hyperparameters
input_dim = X_train_tensor.shape[1]
output_dim = 1
n_hidden_1 = 16
n_hidden_2 = 16
n_epochs = 1000
learning_rate = 0.1


neural_network = NeuralNetwork(input_dim=input_dim, n_hidden_1=n_hidden_1, n_hidden_2=n_hidden_2, output_dim=output_dim)
optimizer = torch.optim.Adam(neural_network.parameters(), lr=learning_rate)
loss = nn.MSELoss()

for epoch in range(n_epochs):
    neural_network.train()
    optimizer.zero_grad()

    y_pred = neural_network(X_train_tensor).flatten()
    loss_value = loss(y_pred, y_train_tensor)

    loss_value.backward()
    optimizer.step()


neural_network.eval()
with torch.no_grad():
    predictions = neural_network(X_test_tensor).flatten()
    metric = torch.sqrt(loss(predictions, y_test_tensor)).item()

print(f"Neurons_1: {n_hidden_1}, Neurons_2: {n_hidden_2}, RMSE: {metric:.4f}")

predicted = pd.DataFrame(predictions.numpy(), columns=['temperature'])
actual = pd.DataFrame(y_test_tensor.numpy(), columns=['temperature'])


fig, ax = plt.subplots(figsize=[20, 6])
indices = range(len(predicted))
plt.bar(indices, predicted['temperature'], color='steelblue', label='Predicted', alpha=0.7, width=0.4, align='center')
plt.bar(indices, actual['temperature'], color='coral', label='Actual', alpha=0.7, width=0.2, align='edge')
plt.title('Star Temperature (K) Predicted vs Actual', fontsize=16)
plt.xlabel('Stars', fontsize=14)
plt.ylabel('Temperature (K)', fontsize=14)
ax.legend()

plt.show()
# Out:
# Neurons_1: 16, Neurons_2: 16, RMSE: 4292.1162

# %% [markdown]
# **Вывод**:
# - Метрика значительно улучшилась и теперь составляет 4292.1162 на тесте.
# - Из диаграммы видно, что модель неплохо справляется с предсказаниями, особенно на более низких температурах. Учитывая очень больное стандартное отклонение в таргете, это достаточно неплохой результата.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> После всех исправлений нужно будет еще раз посмотреть на метрики, возможно придется исправлять выводы
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <b>🎓 Комментарий студента:</b> Сделано.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Отлично получилось! Нейросеть хорошо справляется с прогнозом
# </div>

# %% [markdown]
# ## 3.4 Подбор размера батчей и дропаутов

# %% [markdown]
# Поскольку лучший результат был достигнут с двухслойной конфигурацией (16 нейронов в первом слое и 16 во втором), я буду использовать эти параметры для нейронной сети, чтобы далее оптимизировать размер батча и dropout.

# %%
# Set the parameters
n_hidden_1 = 16
n_hidden_2 = 16
dropout_rates = [0.0, 0.5, 0.9]
batch_sizes = [60, 120, 240]

# Определение модели
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, n_hidden_1, n_hidden_2, output_dim, dropout_rate=0.0):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, n_hidden_1)
        self.act1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(n_hidden_1, n_hidden_2)
        self.act2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout_rate)
        self.fc3 = nn.Linear(n_hidden_2, output_dim)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act1(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = self.act2(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        return x

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# Цикл обучения для разных значений dropout_rate и batch_size
for dropout_rate in dropout_rates:
    for batch_size in batch_sizes:
        print(f"Training with dropout_rate={dropout_rate}, batch_size={batch_size}")
        

        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        model = NeuralNetwork(input_dim=input_dim, n_hidden_1=n_hidden_1, n_hidden_2=n_hidden_2, output_dim=output_dim, dropout_rate=dropout_rate)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

       
        for epoch in range(n_epochs):
            model.train()
            for X_batch, y_batch in train_loader:
                optimizer.zero_grad()
                y_pred = model(X_batch).flatten()
                loss_value = loss(y_pred, y_batch)
                loss_value.backward()
                optimizer.step()

        model.eval()
        with torch.no_grad():
            test_preds = []
            test_targets = []
            for X_batch, y_batch in test_loader:
                preds = model(X_batch).flatten()
                test_preds.append(preds)
                test_targets.append(y_batch)

            test_preds = torch.cat(test_preds)
            test_targets = torch.cat(test_targets)
            rmse = root_mean_squared_error(test_targets, test_preds)
            print(f"Dropout: {dropout_rate}, Batch Size: {batch_size}, RMSE: {rmse}")
# Out:
# Training with dropout_rate=0.0, batch_size=60
# Dropout: 0.0, Batch Size: 60, RMSE: 4179.357851981147
# Training with dropout_rate=0.0, batch_size=120
# Dropout: 0.0, Batch Size: 120, RMSE: 4148.302809465536
# Training with dropout_rate=0.0, batch_size=240
# Dropout: 0.0, Batch Size: 240, RMSE: 4354.402120736693
# Training with dropout_rate=0.5, batch_size=60
# Dropout: 0.5, Batch Size: 60, RMSE: 3746.5261615636073
# Training with dropout_rate=0.5, batch_size=120
# Dropout: 0.5, Batch Size: 120, RMSE: 3873.7220354194574
# Training with dropout_rate=0.5, batch_size=240
# Dropout: 0.5, Batch Size: 240, RMSE: 3609.360562649045
# Training with dropout_rate=0.9, batch_size=60
# Dropout: 0.9, Batch Size: 60, RMSE: 6508.579671401284
# Training with dropout_rate=0.9, batch_size=120
# Dropout: 0.9, Batch Size: 120, RMSE: 5895.754090984225
# Training with dropout_rate=0.9, batch_size=240
# Dropout: 0.9, Batch Size: 240, RMSE: 5932.817582364863

# %% [markdown]
# **Вывод**:
# - Метрика ещё улучшилась и теперь составляет 3609.
# - Используем уже обученную модель с лучшими параметрами построим график.

# %%
dropout_rate_best = 0.5  # Лучший dropout
batch_size_best = 240  # Лучший batch size

n_hidden_1 = 16
n_hidden_2 = 16
input_dim = X_train_tensor.shape[1]  
output_dim = 1  
n_epochs = 50  
loss_fn = nn.MSELoss()  

train_loader = DataLoader(train_dataset, batch_size=batch_size_best, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size_best, shuffle=False)

model = NeuralNetwork(input_dim=input_dim, n_hidden_1=n_hidden_1, n_hidden_2=n_hidden_2, output_dim=output_dim, dropout_rate=dropout_rate_best)
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

for epoch in range(n_epochs):
    model.train()
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        y_pred = model(X_batch).flatten()
        loss_value = loss_fn(y_pred, y_batch)
        loss_value.backward()
        optimizer.step()

model.eval()
with torch.no_grad():
    test_preds = []
    test_targets = []
    for X_batch, y_batch in test_loader:
        preds = model(X_batch).flatten()
        test_preds.append(preds)
        test_targets.append(y_batch)

    test_preds = torch.cat(test_preds)
    test_targets = torch.cat(test_targets)


# Построение графика для предсказанных и реальных значений
predicted = pd.DataFrame(test_preds.numpy(), columns=['temperature'])
actual = pd.DataFrame(test_targets.numpy(), columns=['temperature'])

fig, ax = plt.subplots(figsize=[20, 6])
indices = range(len(predicted))
plt.bar(indices, predicted['temperature'], color='steelblue', label='Predicted', alpha=0.7, width=0.4, align='center')
plt.bar(indices, actual['temperature'], color='coral', label='Actual', alpha=0.7, width=0.2, align='edge')

plt.title('Star Temperature (K) Predicted vs Actual', fontsize=16)
plt.xlabel('Stars', fontsize=14)
plt.ylabel('Temperature (K)', fontsize=14)
ax.legend()

plt.show()

# %% [markdown]
# **Вывод:**
#
# Не смотря на то, что метрика упала, модель начала занижать предсказания. Вероятно, причина в том, что в датасете есть сильные выбросы и смещение, которое модель не может корректно обработать. Например, значения таргета имеют большой разброс, и модель вероятно концентрируется на более частых (или менее экстремальных) значениях и не учитывает экстремальные отклонения.
#
# Таким образом, в качестве оптимальной модели считаю целесообразно выбрать вторую базовую в следующей конфигурации:
#
# - 1-ый линейный слой - число нейронов на входе равное числу столбцов в обработанном тензоре, 16 нейронов на выходе
# ктивация ReLU
# - 2-й линейный слой - 16 нейронов на входе, 16 нейронов на выходе
# активация ReLU
# - Линейный выходной слой 16 нейронов на входе, 1 на выходе
# - Без деления на батчи и дропаутов.

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Здесь нужно добавить описание графика и сравнение его с предыдущими (которые будут добавлены)</s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <b>🎓 Комментарий студента:</b> Сделано.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Молодец!
# </div>

# %% [markdown]
# **Заключение**
#
# В настоящем проекте я изучила, очистила и подготовила данные. Затем я разработала две нейронные сети с различными конфигурациями, чтобы оценить их производительность. Также была выполнена оптимизация размера батча и dropout для дальнейшего улучшения моделей.
#
# Лучшие результаты были достигнуты с использованием базовой нейронной сети с двумя скрытыми слоями, что подчеркивает эффективность этой более простой архитектуры для данной задачи. Этот результат говорит о том, что базовая модель находит оптимальный баланс между сложностью и обобщением, что делает её хорошо подходящей для предсказания целевой переменной, особенно для более низких температур.
#
# Оптимальная модель:
#
# - 1-ый линейный слой - число нейронов на входе равное числу столбцов в обработанном тензоре, 16 нейронов на выходе
# ктивация ReLU
# - 2-й линейный слой - 16 нейронов на входе, 16 нейронов на выходе
# активация ReLU
# - Линейный выходной слой 16 нейронов на входе, 1 на выходе
# - Без деления на батчи и дропаутов.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Отличная работа! Было очень приятно проверять твой проект!
#
# Оставлю хороший учебник по ML:
# +  https://academy.yandex.ru/handbook/ml
#
# Немного новостей с мира DL(вдруг заинтересует):
# +  https://habr.com/ru/company/ods/blog/686962/
#
# Вот тут проходят всякие соревнования, можешь себя попробовать:
# +  https://hacks-ai.ru/
#
#
# Возможно, что нить пригодится:
# +  https://arxiv.org/ftp/arxiv/papers/2201/2201.00650.pdf
# +  https://github.com/slgero/testovoe
#
#
# Курс от МФТИ математика для DS:
#
# +  https://www.youtube.com/watch?v=xccjt6lOoow&list=PLk4h7dmY2eYHHTyfLyrl7HmP-H3mMAW08&index=1
#
#
# Тут много соревнований/лекций:
#
# +  https://ods.ai/
#
# stepic NLP/CV:
#
# +  https://stepik.org/course/54098/syllabus
# +  https://stepik.org/course/50352/syllabus
#
# Еще есть от ВШЭ:
#
# +  https://www.youtube.com/watch?v=mwjQaNt8qxk&list=PLEwK9wdS5g0og-DcF1apxutSM0GDLHz_3&ab_channel=%D0%A4%D0%9A%D0%9D%D0%92%D0%A8%D0%AD%E2%80%94%D0%B4%D0%B8%D1%81%D1%82%D0%B0%D0%BD%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D0%B5%D0%B7%D0%B0%D0%BD%D1%8F%D1%82%D0%B8%D1%8F
# +  https://github.com/hse-ds/iad-deep-learning
#
# Удачи в следующих проектах!!!
# </div>
